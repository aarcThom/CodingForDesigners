# %%
# creating a dictionary where architect names are the KEYS and nationalities are the VALUES.
arch_dict = {'le corbusier':'swiss-french', 'zaha hadid':'iraqi-british', 'arthur erickson':'canadian', 'patrica patkau':'canadian'}

# %%
arch_dict
# Out:
# {'le corbusier': 'swiss-french',
#  'zaha hadid': 'iraqi-british',
#  'arthur erickson': 'canadian',
#  'patrica patkau': 'canadian'}

# %%
removed_nat = arch_dict.pop("zaha hadid")

print(removed_nat)
# Out:
# iraqi-british

# %%
# creating a dictionary where architect names are the KEYS and nationalities are the VALUES.
arch_dict = {'le corbusier':'swiss-french', 'zaha hadid':'iraqi-british', 'arthur erickson':'canadian', 'patrica patkau':'canadian'}

# %%
# create a list of keys to delete
del_keys = []

for key in arch_dict:
    if arch_dict[key] == "canadian":
        del_keys.append(key)

for d_key in del_keys:
    arch_dict.pop(d_key)

arch_dict
# Out:
# {'le corbusier': 'swiss-french', 'zaha hadid': 'iraqi-british'}

# %%
# you guys are so smart!
class_grades = {'des450':[89.5, 90.2, 99.1, 92.3, 94.4], 'arch577':[95, 99, 100, 89, 93, 88]}


# take the average of each class
for section in class_grades:
    section_grades = class_grades[section]
    
    section_avg = sum(section_grades) / len(section_grades)

    print(f"The class average of {section} is {section_avg}%")
# Out:
# The class average of des450 is 93.1%
# The class average of arch577 is 94.0%

# %%
arch_dict = {'le corbusier':'swiss-french', 'zaha hadid':'iraqi-british', 'arthur erickson':'canadian', 'patrica patkau':'canadian'}

# %%
designer_dict = arch_dict

# %%
designer_dict.pop("arthur erickson")
# Out:
# 'canadian'

# %%
designer_dict
# Out:
# {'le corbusier': 'swiss-french',
#  'zaha hadid': 'iraqi-british',
#  'patrica patkau': 'canadian'}

# %%
arch_dict
# Out:
# {'le corbusier': 'swiss-french',
#  'zaha hadid': 'iraqi-british',
#  'patrica patkau': 'canadian'}

# %%
arch_dict = {'le corbusier':'swiss-french', 'zaha hadid':'iraqi-british', 'arthur erickson':'canadian', 'patrica patkau':'canadian'}

# %%
designer_dict = arch_dict.copy()

# %%
designer_dict.pop("arthur erickson")
# Out:
# 'canadian'

# %%
designer_dict
# Out:
# {'le corbusier': 'swiss-french',
#  'zaha hadid': 'iraqi-british',
#  'patrica patkau': 'canadian'}

# %%
arch_dict
# Out:
# {'le corbusier': 'swiss-french',
#  'zaha hadid': 'iraqi-british',
#  'arthur erickson': 'canadian',
#  'patrica patkau': 'canadian'}

# %%
file_object = open("C:/Users/tgaudin/repos/CodingForDesigners/0602_dictionaries/data/pokemon.json", mode="r", encoding="utf-8")
# do stuff with the file
file_object.close()
